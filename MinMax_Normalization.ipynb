# %%
import pandas as pd

FinalSuperset_17 = pd.read_csv("FinalSuperset\\FinalSuperset_17.csv")
FinalSuperset_17_temp = FinalSuperset_17.copy()

# minmax normalization
FinalSuperset_17_temp['API_17'] = (FinalSuperset_17_temp['API_17'] - FinalSuperset_17_temp['API_17'].min()) / (FinalSuperset_17_temp['API_17'].max() - FinalSuperset_17_temp['API_17'].min())
FinalSuperset_17_temp['Temp_17'] = (FinalSuperset_17_temp['Temp_17'] - FinalSuperset_17_temp['Temp_17'].min()) / (FinalSuperset_17_temp['Temp_17'].max() - FinalSuperset_17_temp['Temp_17'].min())
FinalSuperset_17_temp['Humidity_17'] = (FinalSuperset_17_temp['Humidity_17'] - FinalSuperset_17_temp['Humidity_17'].min()) / (FinalSuperset_17_temp['Humidity_17'].max() - FinalSuperset_17_temp['Humidity_17'].min())
FinalSuperset_17_temp['Precip_17'] = (FinalSuperset_17_temp['Precip_17'] - FinalSuperset_17_temp['Precip_17'].min()) / (FinalSuperset_17_temp['Precip_17'].max() - FinalSuperset_17_temp['Precip_17'].min())
FinalSuperset_17_temp['Wind_17'] = (FinalSuperset_17_temp['Wind_17'] - FinalSuperset_17_temp['Wind_17'].min()) / (FinalSuperset_17_temp['Wind_17'].max() - FinalSuperset_17_temp['Wind_17'].min())
FinalSuperset_17_temp['Vegetation_17'] = (FinalSuperset_17_temp['Vegetation_17'] - FinalSuperset_17_temp['Vegetation_17'].min()) / (FinalSuperset_17_temp['Vegetation_17'].max() - FinalSuperset_17_temp['Vegetation_17'].min())
FinalSuperset_17_temp['Traffic_17'] = (FinalSuperset_17_temp['Traffic_17'] - FinalSuperset_17_temp['Traffic_17'].min()) / (FinalSuperset_17_temp['Traffic_17'].max() - FinalSuperset_17_temp['Traffic_17'].min())
FinalSuperset_17_temp['Population_17'] = (FinalSuperset_17_temp['Population_17'] - FinalSuperset_17_temp['Population_17'].min()) / (FinalSuperset_17_temp['Population_17'].max() - FinalSuperset_17_temp['Population_17'].min())
FinalSuperset_17_temp['Altitude'] = (FinalSuperset_17_temp['Altitude'] - FinalSuperset_17_temp['Altitude'].min()) / (FinalSuperset_17_temp['Altitude'].max() - FinalSuperset_17_temp['Altitude'].min())
FinalSuperset_17_temp['Building'] = (FinalSuperset_17_temp['Building'] - FinalSuperset_17_temp['Building'].min()) / (FinalSuperset_17_temp['Building'].max() - FinalSuperset_17_temp['Building'].min())
FinalSuperset_17_temp['Year'] = '2017'
FinalSuperset_17_temp = FinalSuperset_17_temp.rename(columns=lambda x: x.replace('_17', ''))


FinalSuperset_18 = pd.read_csv("FinalSuperset\\FinalSuperset_18.csv")
FinalSuperset_18_temp = FinalSuperset_18.copy()

# minmax normalization
FinalSuperset_18_temp['API_18'] = (FinalSuperset_18_temp['API_18'] - FinalSuperset_18_temp['API_18'].min()) / (FinalSuperset_18_temp['API_18'].max() - FinalSuperset_18_temp['API_18'].min())
FinalSuperset_18_temp['Temp_18'] = (FinalSuperset_18_temp['Temp_18'] - FinalSuperset_18_temp['Temp_18'].min()) / (FinalSuperset_18_temp['Temp_18'].max() - FinalSuperset_18_temp['Temp_18'].min())
FinalSuperset_18_temp['Humidity_18'] = (FinalSuperset_18_temp['Humidity_18'] - FinalSuperset_18_temp['Humidity_18'].min()) / (FinalSuperset_18_temp['Humidity_18'].max() - FinalSuperset_18_temp['Humidity_18'].min())
FinalSuperset_18_temp['Precip_18'] = (FinalSuperset_18_temp['Precip_18'] - FinalSuperset_18_temp['Precip_18'].min()) / (FinalSuperset_18_temp['Precip_18'].max() - FinalSuperset_18_temp['Precip_18'].min())
FinalSuperset_18_temp['Wind_18'] = (FinalSuperset_18_temp['Wind_18'] - FinalSuperset_18_temp['Wind_18'].min()) / (FinalSuperset_18_temp['Wind_18'].max() - FinalSuperset_18_temp['Wind_18'].min())
FinalSuperset_18_temp['Vegetation_18'] = (FinalSuperset_18_temp['Vegetation_18'] - FinalSuperset_18_temp['Vegetation_18'].min()) / (FinalSuperset_18_temp['Vegetation_18'].max() - FinalSuperset_18_temp['Vegetation_18'].min())
FinalSuperset_18_temp['Traffic_18'] = (FinalSuperset_18_temp['Traffic_18'] - FinalSuperset_18_temp['Traffic_18'].min()) / (FinalSuperset_18_temp['Traffic_18'].max() - FinalSuperset_18_temp['Traffic_18'].min())
FinalSuperset_18_temp['Population_18'] = (FinalSuperset_18_temp['Population_18'] - FinalSuperset_18_temp['Population_18'].min()) / (FinalSuperset_18_temp['Population_18'].max() - FinalSuperset_18_temp['Population_18'].min())
FinalSuperset_18_temp['Altitude'] = (FinalSuperset_18_temp['Altitude'] - FinalSuperset_18_temp['Altitude'].min()) / (FinalSuperset_18_temp['Altitude'].max() - FinalSuperset_18_temp['Altitude'].min())
FinalSuperset_18_temp['Building'] = (FinalSuperset_18_temp['Building'] - FinalSuperset_18_temp['Building'].min()) / (FinalSuperset_18_temp['Building'].max() - FinalSuperset_18_temp['Building'].min())
FinalSuperset_18_temp['Year'] = '2018'
FinalSuperset_18_temp = FinalSuperset_18_temp.rename(columns=lambda x: x.replace('_18', ''))


FinalSuperset_19 = pd.read_csv("FinalSuperset\\FinalSuperset_19.csv")
FinalSuperset_19_temp = FinalSuperset_19.copy()

API_19_min = FinalSuperset_19['API_19'].min()
API_19_max = FinalSuperset_19['API_19'].max()
# minmax normalization
FinalSuperset_19_temp['API_19'] = (FinalSuperset_19_temp['API_19'] - API_19_min) / (API_19_max - API_19_min)
FinalSuperset_19_temp['Temp_19'] = (FinalSuperset_19_temp['Temp_19'] - FinalSuperset_19_temp['Temp_19'].min()) / (FinalSuperset_19_temp['Temp_19'].max() - FinalSuperset_19_temp['Temp_19'].min())
FinalSuperset_19_temp['Humidity_19'] = (FinalSuperset_19_temp['Humidity_19'] - FinalSuperset_19_temp['Humidity_19'].min()) / (FinalSuperset_19_temp['Humidity_19'].max() - FinalSuperset_19_temp['Humidity_19'].min())
FinalSuperset_19_temp['Precip_19'] = (FinalSuperset_19_temp['Precip_19'] - FinalSuperset_19_temp['Precip_19'].min()) / (FinalSuperset_19_temp['Precip_19'].max() - FinalSuperset_19_temp['Precip_19'].min())
FinalSuperset_19_temp['Wind_19'] = (FinalSuperset_19_temp['Wind_19'] - FinalSuperset_19_temp['Wind_19'].min()) / (FinalSuperset_19_temp['Wind_19'].max() - FinalSuperset_19_temp['Wind_19'].min())
FinalSuperset_19_temp['Vegetation_19'] = (FinalSuperset_19_temp['Vegetation_19'] - FinalSuperset_19_temp['Vegetation_19'].min()) / (FinalSuperset_19_temp['Vegetation_19'].max() - FinalSuperset_19_temp['Vegetation_19'].min())
FinalSuperset_19_temp['Traffic_19'] = (FinalSuperset_19_temp['Traffic_19'] - FinalSuperset_19_temp['Traffic_19'].min()) / (FinalSuperset_19_temp['Traffic_19'].max() - FinalSuperset_19_temp['Traffic_19'].min())
FinalSuperset_19_temp['Population_19'] = (FinalSuperset_19_temp['Population_19'] - FinalSuperset_19_temp['Population_19'].min()) / (FinalSuperset_19_temp['Population_19'].max() - FinalSuperset_19_temp['Population_19'].min())
FinalSuperset_19_temp['Altitude'] = (FinalSuperset_19_temp['Altitude'] - FinalSuperset_19_temp['Altitude'].min()) / (FinalSuperset_19_temp['Altitude'].max() - FinalSuperset_19_temp['Altitude'].min())
FinalSuperset_19_temp['Building'] = (FinalSuperset_19_temp['Building'] - FinalSuperset_19_temp['Building'].min()) / (FinalSuperset_19_temp['Building'].max() - FinalSuperset_19_temp['Building'].min())
FinalSuperset_19_temp['Year'] = '2019'
FinalSuperset_19_temp = FinalSuperset_19_temp.rename(columns=lambda x: x.replace('_19', ''))


FinalSuperset_joined = pd.concat([FinalSuperset_17_temp, FinalSuperset_18_temp, FinalSuperset_19_temp], ignore_index=True)
FinalSuperset_joined = FinalSuperset_joined.sort_values('API')

print(FinalSuperset_joined)

FinalSuperset_joined.to_csv("FinalSuperset\\FinalSuperset_joined.csv", index=False)
